# %% [markdown]
# Task 2: Exploratory Data Analysis (EDA)

# %%
# To Import required libraries 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# To Load cleaned dataset

data = pd.read_csv('Salary_Data_Cleaned.csv')
data.head()
# Out:
#         Age  Gender  Education Level  Job Title  Years of Experience    Salary
# 0 -0.212844       1                0        177            -0.510826 -0.480013
# 1 -0.738262       0                3         18            -0.841010 -0.953834
# 2  1.494766       1                5        145             1.140091  0.657157
# 3  0.312575       0                0        116            -0.180643 -1.048598
# 4  2.414248       1                3         26             1.965549  1.604799

# %%
# To get Summary statistics

data.describe(include='all')
# Out:
#                Age       Gender  Education Level    Job Title  \
# count  6556.000000  6556.000000      6556.000000  6556.000000
# mean     -0.062896     0.546675         2.519524    93.600824
# std       0.917160     0.500300         1.805091    58.402925
# min      -1.657744     0.000000         0.000000     0.000000
# 25%      -0.738262     0.000000         1.000000    42.000000
# 50%      -0.212844     1.000000         2.000000    96.000000
# 75%       0.443929     1.000000         4.000000   158.000000
# max       2.545603     2.000000         6.000000   192.000000
#
#        Years of Experience       Salary
# count          6556.000000  6556.000000
# mean             -0.057768    -0.032225
# std               0.921037     0.987179
# min              -1.336285    -2.179135
# 25%              -0.841010    -0.859070
# 50%              -0.180643    -0.044098
# 75%               0.479724     0.846685
# max               2.791008     2.552440

# %%
# Histograms for numeric features

data.hist(figsize=(12,8), bins=30)
plt.suptitle("Histograms of Numeric Features")
plt.show()

# Boxplots for numeric features

plt.figure(figsize=(12,5))
for i, column in enumerate(['Age', 'Years of Experience', 'Salary'], 1):
    plt.subplot(1,3,i)
    sns.boxplot(y=df[column])
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
# Correlation matrix and heatmap

corr = data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Pairplot for feature relationships

sns.pairplot(data[['Age','Years of Experience','Salary']], diag_kind='kde')
plt.show()
# Out:
# C:\Users\Navya M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Navya M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Navya M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
